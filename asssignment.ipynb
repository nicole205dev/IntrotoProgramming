# %%
# Ask the user to enter the number of days
days = int(input("Enter the number of days: "))

# Convert days into seconds
seconds = days * 24 * 60 * 60

# Display the result
print("Number of seconds:", seconds)

# %%
# Import the math module so we can use pi
import math

# Ask the user to enter the radius
radius = float(input("Enter the radius: "))

# Calculate the volume of the sphere
# The ** operator is used to calculate r cubed
volume = (4 / 3) * math.pi * (radius ** 3)

# Display the result
print("Volume of the sphere:", volume)

# %%
# Function to calculate the area of a square
def calculate_area(side):
    return side ** 2

# Function to calculate the perimeter of a square
def calculate_perimeter(side):
    return side * 4

# Ask the user to enter the side length
side = float(input("Enter the side length of the square: "))

# Calculate and display the area and perimeter
print("Area:", calculate_area(side))
print("Perimeter:", calculate_perimeter(side))

# %%
# Function to check whether a character is uppercase or lowercase
def check_case(character):
    if character.isupper():
        print("The character is uppercase.")
    elif character.islower():
        print("The character is lowercase.")
    else:
        print("The character is not a letter.")

# Ask the user to enter a character
character = input("Enter a character: ")

# Check the character
check_case(character)

# %%
# Set the initial values
x = 0
y = 20

# Repeat the calculation until y is less than 6
while True:
    # Subtract 4 from y
    y = y - 4

    # Add 2/y to x
    x = x + (2 / y)

    # Stop the loop when y is less than 6
    if y < 6:
        break

# Display the final value of x
print("The value of x is:", x)

# %%
# Create an empty list to store the values
values = []

# Use a loop to ask the user for 5 values
for i in range(5):
    value = float(input("Enter a value: "))
    values.append(value)

# Calculate the average of the values
average = sum(values) / len(values)

# Display the values entered and their average
print("Values entered:", values)
print("Average:", average)
